# %%
import numpy as np
import matplotlib.pyplot as plt

from expWorkbench import ema_logging, load_results, CategoricalUncertainty
from analysis import plotting, plotting_util
from analysis.plotting import lines, KDE, kde_over_time, multiple_densities, envelopes
from analysis.pairs_plotting import pairs_scatter
from analysis.plotting_util import plot_kde, ENVELOPE, ENV_LIN, VIOLIN

ema_logging.log_to_stderr(ema_logging.INFO);

#load the data
fn = r'C:\Users\rluteijn\Documents\GitHub\msc_thesis\src\data\100 runs 12 jan.tar.gz'
experiments, outcomes = load_results(fn)
results = (experiments, outcomes)
# Out:
# [INFO/MainProcess] results loaded succesfully from C:\Users\rluteijn\Documents\GitHub\msc_thesis\src\data\100 runs 12 jan.tar.gz

# %%
fig, axesdict = lines(results, 
                  outcomes_to_show = [
                    "conflict-no-interaction", 
                    "conflict-too-long",
                    ],
                  group_by = None,
                  grouping_specifiers = None,
                  density='',
#                   fill=False,
                  legend=True,
                  titles={},
                  ylabels={},
                  log=True)
plt.show()
# Out:
# C:\Users\rluteijn\Documents\GitHub\EMAworkbench\src\analysis\plotting_util.py:445: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if time==None:

# %%
fig, axesdict = envelopes(results, 
                  outcomes_to_show = [
                    "states-missing-resources", 
                    "trade-severed",
                    ],
                  group_by = None,
                  grouping_specifiers = None,
                  density='',
                  fill=False,
                  legend=True,
                  titles={},
                  ylabels={},
                  log=True)
plt.show()

# %%
fig, axesdict = envelopes(results, 
                  outcomes_to_show = [
                   "inflection-1", 
                    "inflection-2", 
                    "inflection-3", 
                    "inflection-4", 
                    "inflection-5", 
                    "inflection-6", 
                    "inflection-7", 

                    ],
                  group_by = None,
                  grouping_specifiers = None,
                  density='',
                  fill=False,
                  legend=True,
                  titles={},
                  ylabels={},
                  log=True)
plt.show()

# %%
fix, axesdict = pairs_scatter(results, 
                  outcomes_to_show = [
                    "inflection-state1", 
                    "FPR-satisfaction-state1", 
                    "power-1", 
                    "interdependence-1", 
                    "amount-of-conflicts1", 
                    "amount-of-conflicts2",
],
                  group_by = None,
                  grouping_specifiers = None,
                  ylabels = {},
                  legend=True,
                  point_in_time=-1,
                  filter_scalar=True
                  )
plt.show()

# %%
fig, axesdict = lines(results, 
                  outcomes_to_show = [
                   "FPR-satisfaction-state1",
                    ],
                  group_by = None,
                  grouping_specifiers = None,
                  density='',
#                   fill=False,
                  legend=True,
                  titles={},
                  ylabels={},
                  log=True
                  )
plt.show()

# %%
fig, axesdict = lines(results, 
                  outcomes_to_show = [
                    "major-power-war-counter",
                    ],
                  group_by = None,
                  grouping_specifiers = None,
                  density='',
#                   fill=False,
                  legend=True,
                  titles={},
                  ylabels={},
#                   log=True
                  )
plt.show()

# %%
fig, axesdict = lines(results, 
                  outcomes_to_show = [
                    "power-transition-counter", 
                    ],
                  group_by = None,
                  grouping_specifiers = None,
                  density='',
#                   fill=False,
                  legend=True,
                  titles={},
                  ylabels={},
                  log=True)
plt.show()
