# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy

from expWorkbench import ema_logging, load_results, save_results
from analysis.plotting import lines, KDE, envelopes
from analysis import plotting, plotting_util
from analysis.plotting import lines, KDE, kde_over_time, multiple_densities
from analysis.pairs_plotting import pairs_scatter
from analysis.plotting_util import plot_kde, ENVELOPE, ENV_LIN

ema_logging.log_to_stderr(ema_logging.INFO);

#load the data
fn = r'C:\Users\rluteijn\Documents\GitHub\msc_thesis\src\data\1000 runs 28 jan.tar.gz'
experiments, outcomes = load_results(fn)
results = (experiments, outcomes)
# Out:
# [INFO/MainProcess] results loaded succesfully from C:\Users\rluteijn\Documents\GitHub\msc_thesis\src\data\1000 runs 28 jan.tar.gz

# %%
# Polarity: Major power wars occur more often in a multipolar world

fig = plt.figure(1)
ax = fig.add_subplot(111)

outcome1 = outcomes["MPW-polarity"]
outcome2 = outcomes["MPW"]
outcome3 = outcomes["Power-end1"]
logical = outcome2 != 0
logical2 = outcome3 != 0
logical3 = logical &(outcome1 == 2)
logical4 = logical &(outcome1 == 3)
logical5 = logical2 & (outcome1 == 2)
logical6 = logical2 & (outcome1 == 3)

plot1 = ax.hist(outcome1[logical2],color='green', log=True, label="Cases of conflict")
plot2 = ax.hist(outcome1[logical],color='red', log=True, label="Cases of major power war")
ax.set_xlabel("Polarity")
ax.set_ylabel("Cases of conflict")
ax.set_xticks((2,3))

# change axis to bipolar and multipolar
ax.set_xticklabels(["bipolarity", "multipolarity"], rotation=45, fontsize=10, ha='center')

#add a legend
ax.legend()

print len(outcome1[logical])
print len(outcome1[logical2])
# 13% of major power conflicts escalate to major power war
print len(outcome1[logical3])
print len(outcome1[logical4])
# 34% of these wars are in a bipolar world, 66% in a multipolar world
print len(outcome1[logical5])
print len(outcome1[logical6])
# 8,8 % of conflicts in bipolarity escalate to major power war, 17,6% of multipolar conflicts escalate to major power war
# Out:
# 64879
# 496040
# 22358
# 42521
# 254145
# 241895

# %%
# Polarization: Major power wars occur more often under conditions of high polarization

fig = plt.figure(1)
ax = fig.add_subplot(111)

outcome1 = outcomes["polarisation"]
outcome2 = outcomes["MPW"]
outcome3 = outcomes["Power-end1"]
outcome4 = outcomes["MPW-polarity"]
logical = (outcome2 != 0) & (outcome1 <= 1)
logical2 = (outcome3 != 0) & (outcome1 <= 1)
logical3 = logical &(outcome4 == 2)
logical4 = logical &(outcome4 == 3)
logical5 = logical2 & (outcome4 == 2)
logical6 = logical2 & (outcome4 == 3)

# histogram of distribution of polarisation in MPW and MP-conflict
ax.hist(outcome1[logical2],50, color='yellow', log=True, label="Cases of conflict")
ax.hist(outcome1[logical],50, color='red', log=False, label="Cases of major power war")

# histogram of distribution of polarisation in MPW, controlling for polarity
ax.hist(outcome1[logical4],50, color='blue', log=False, label="Under conditions of multipolarity")
ax.hist(outcome1[logical3],50, color='green', log=False, label="Under conditions of bipolarity")

# histogram of distribution of polarisation in MP-conflict
# ax.hist(outcome1[logical5],50, color='blue', log=False, label="Under conditions of multipolarity")
# ax.hist(outcome1[logical6],50, color='green', log=False, label="Under conditions of bipolarity")

ax.set_xlabel("Polarisation")
ax.set_ylabel("Cases of conflict")
ax.legend(loc=0)

# ax.annotate(("""Both major powers are 
# without any friendly states"""), (2, 5000), (1.7, 10000))

# ax.annotate(("""One major power is 
# without any friendly states"""), (3, 15000), (2.7, 100000))

# ax.set_xlim([0,1])

# data = [outcome1[logical], outcome1[logical2], outcome1[logical3], outcome1[logical4], 
#         outcome1[logical5], outcome1[logical6]]

# ax.boxplot(data)

# %%
# Ideology: Major powers fight more often against states with dissimilar ideologies

fig = plt.figure(1)
ax = fig.add_subplot(111)

outcome1 = outcomes["MPW-ideology-similarity"]
outcome2 = outcomes["MPW"]
outcome3 = outcomes["Power-end1"]
outcome4 = outcomes["MPW-polarity"]
logical = (outcome2 != 0) 
logical2 = (outcome3 != 0) 
logical3 = logical &(outcome4 == 2)
logical4 = logical &(outcome4 == 3)
logical5 = logical2 & (outcome4 == 2)
logical6 = logical2 & (outcome4 == 3)

# histogram of distribution of polarisation in MPW and MP-conflict
# ax.hist(outcome1[logical2],50, color='yellow', log=False, label="Cases of conflict")
ax.hist(outcome1[logical],50, color='red', log=False, label="Cases of major power war")

# histogram of distribution of polarisation in MPW, controlling for polarity
ax.hist(outcome1[logical4],50, color='blue', log=False, label="Under conditions of multipolarity")
ax.hist(outcome1[logical3],50, color='green', log=False, label="Under conditions of bipolarity")

# histogram of distribution of polarisation in MP-conflict
# ax.hist(outcome1[logical5],50, color='blue', log=False, label="Under conditions of multipolarity")
# ax.hist(outcome1[logical6],50, color='green', log=False, label="Under conditions of bipolarity")

ax.set_xlabel("Ideology similarity")
ax.set_ylabel("Cases of conflict")
ax.legend(loc=0)

# %% [markdown]
# Key findings:
#     - significantly more conflicts among major powers erupt to major power war in multipolarity
#     - the amount of polarisation among the fighting parties is nog significantly different under multipolar or bipolar circumstances
#     - The ideology similarity is not significantly different under multipolar or bipolar circumstances, but:
#         - strange peaks in ideology similarity
#
# Question: what else may be different in multipolarity that would explain the difference?

# %%
# Power: Major power wars occur more often at power parity

fig = plt.figure(1)
ax = fig.add_subplot(111)
a = "MPW"
b = "Inflection-point-end1"
c = "Inflection-point-end2"
d = "Power-end1"
e = "Power-end2"
f = "top-dog"

outcome1 = outcomes[a]
outcome2 = outcomes[b]
outcome3 = outcomes[c]
outcome4 = outcomes[d]
outcome5 = outcomes[e]
outcome6 = abs(outcome4[logical2] - outcome5[logical2])
outcome7 = abs(outcome4[logical] - outcome5[logical])
outcome8 = outcomes[f]

logical3 = (outcome3 == 5) & (outcome2 == 4)
logical4 = (outcome3 == 1) & (outcome2 == 4)
logical5 = (outcome3 == 1) & (outcome2 == 1)
logical6 = (outcome3 == 5) & (outcome2 == 1)
logical7 = (outcome3 == 4) & (outcome2 == 4) & (outcome8 == 3)
logical8 = logical2 & logical7
logical9 = outcome4 != 0
logical2 = outcome1 != 0
logical = logical2 & (logical3 | logical4 | logical5 | logical6)

# ax.scatter(outcome4[logical2],outcome5[logical2] ,color='blue')
# ax.scatter(outcome4[logical8],outcome5[logical8],color='red')
# ax.scatter(outcome4[logical],outcome5[logical],color='green')


# ax.hist(outcome6, color='blue')
ax.hist((abs(outcome4[logical9] - outcome5[logical9])), 50, color='green', label='Difference in power in conflicts')
ax.hist(outcome6, 50, log=True, color='red', label='Difference in power in MPW')
ax.legend()
ax.set_xlabel("Difference in power")
ax.set_ylabel("Cases")

# %% [markdown]
# Based on this histogram, not much may be said about power parity other than that very high differentials in power do not seem to occur in wars, but do occur in conflicts

# %%
# Power: Major power wars occur more often at power parity

fig = plt.figure(1)
ax = fig.add_subplot(111)
a = "MPW"
b = "Inflection-point-end1"
c = "Inflection-point-end2"
d = "Power-end1"
e = "Power-end2"
f = "top-dog"

outcome1 = outcomes[a]
outcome4 = outcomes[d]
outcome5 = outcomes[e]
outcome6 = abs(outcome4[logical2] - outcome5[logical2]) ## power difference
outcome7 = outcome6 / outcome4[logical2]  
outcome8 = outcome6 / outcome5[logical2] 

#  select only those cases where the percentage of power differential is larger than some value
outcome9 = np.zeros(outcome7.shape)
percentage = 0.05
# for j, entry in enumerate(outcome9):
for j, item in enumerate(outcome7):
    if item > percentage:
        outcome9[j] = 1
          
for j, item in enumerate(outcome8):
    if item > percentage:
        outcome9[j] = 1
    
# 1 if either outcome 7 or outcome 8 > percentage
#  otherwise 0

logical9 = outcome4 != 0
logical2 = outcome1 != 0
logical = outcome9 == 1
logical3 = outcome9 == 0

outcome2 = outcome4[logical2]
outcome3 = outcome5[logical2]


outcome16 = abs(outcome4[logical9] - outcome5[logical9]) ## power difference
outcome17 = outcome16 / outcome4[logical9]  
outcome18 = outcome16 / outcome5[logical9] 

#  select only those cases where the percentage of power differential is larger than some value
outcome19 = np.zeros(outcome17.shape)
# for j, entry in enumerate(outcome9):
for j, item in enumerate(outcome17):
    if item > percentage:
        outcome19[j] = 1
          
for j, item in enumerate(outcome18):
    if item > percentage:
        outcome19[j] = 1
outcome10 = outcome4[logical9]
outcome11 = outcome5[logical9]
logical12 = outcome19 == 1
logical13 = outcome19 == 0
# for MPW
# ax.scatter(outcome2[logical3],outcome3[logical3],color='red', label='MPW fought at power parity')
# ax.scatter(outcome2[logical],outcome3[logical],color='green', label='MPW fought at power disparity')

# for all MP conflicts
ax.scatter(outcome10[logical13],outcome11[logical13],color='red', label='MPW fought at power parity')
ax.scatter(outcome10[logical12],outcome11[logical12],color='green', label='MPW fought at power disparity')

ax.legend()
ax.set_xlabel("Power state 1")
ax.set_ylabel("Power state 1")
 
print len(outcome10[logical13])
print len(outcome10)

print len(outcome2[logical3])
print len(outcome2)

ax.annotate(('Percentage at power parity ='), (12.5,17))
ax.annotate(('Power parity percentage ='), (12.5,16))
ax.annotate(b, (18.4,17))
ax.annotate(percentage, (18,16))

#  0.7 --> pop = 64%, MPW = 68.5%
#  0.5 --> pop = 53%, MPW =56%
#  0.25 --> pop = 34%, MPW = 34%
#  0.1 --> pop = 16.7%, MPW = 15.6%
#  0.05 --> pop = 8.9%, MPW = 8.5 %
# Out:
# 44556
# 496040
# 5484
# 64879

# %%
#  Expected transition: Major power wars occur more often when the expectation of a power transition is present

# fig = plt.figure(1)
# ax = fig.add_subplot(111)
a = "MPW"
b = "expected-transition"
c = "top-dog"

outcome1 = outcomes[a]
outcome2 = outcomes[b]
outcome3 = outcomes[c]

logical = outcome1 != 0
logical2 = outcome3 != 0
logical3 = logical & (outcome3 == 1)
logical4 = logical & (outcome3 == 2)
logical5 = logical & (outcome3 == 3)
logical6 = outcome2 == 1
logical7 = outcome2 == 2

# ax.scatter(outcome4[logical2],outcome5[logical2] ,color='blue')
# ax.scatter(outcome4[logical8],outcome5[logical8],color='red')
# ax.scatter(outcome4[logical],outcome5[logical],color='green')


# ax.hist(outcome6, color='blue')
# ax.hist((abs(outcome4[logical9] - outcome5[logical9])), 50, color='green', label='Difference in power in conflicts')
# ax.hist(outcome6, 50, log=True, color='red', label='Difference in power in MPW')

# ax.hist(outcome2[logical2])
# ax.hist(outcome2[logical])

# ax.scatter(outcome2[logical], outcome3[logical], color='green', label= 'cases in MPW')

ax.legend()
ax.set_xlabel("Difference in power")
ax.set_ylabel("Cases")

print len(outcome2[logical3 & logical6])
print len(outcome2[logical4 & logical6])
print len(outcome2[logical5 & logical6])
print len(outcome2[logical3 & logical7])
print len(outcome2[logical4 & logical7])
print len(outcome2[logical5 & logical7])

# large amount of wars when the expectation of a power transition is present, but neither party is top dog
# Out:
# 4133
# 3801
# 28509
# 4712
# 4411
# 19313

# %%
# Inflection point: Major power wars happen most often between a rising major power and a declining major power

# fig = plt.figure(1)
# ax = fig.add_subplot(111)
a = "MPW"
b = "Inflection-point-end1"
c = "Inflection-point-end2"
d = "Power-end1"
e = "Power-end2"
f = "top-dog"

outcome1 = outcomes[a]
outcome2 = outcomes[b]
outcome3 = outcomes[c]
outcome4 = outcomes[d]
outcome5 = outcomes[e]
outcome6 = outcomes[f]

logical1 = outcome1 != 0
logical2 = outcome4 != 0
# outcome2 = outcome2[logical1]
# outcome3 = outcome3[logical1]
logical3 = (outcome2 == 1) & (outcome3 == 5)
logical4 = (outcome2 == 1) & (outcome3 == 4)
logical5 = (outcome2 == 4) & (outcome3 == 1)
logical6 = (outcome2 == 4) & (outcome3 == 5)
logical7 = (outcome2 == 5) & (outcome3 == 1)
logical8 = (outcome2 == 5) & (outcome3 == 4)
logical9 = (outcome2 == 1) & (outcome3 == 1)

logical = (logical3 | logical4 | logical5 | logical6 | logical7 | logical8 | logical9 )

print len(outcome2[logical])
print len(outcome2[logical & logical1])
print len(outcome2[logical2])
# ax.scatter(outcome20, outcome21, color='red', label='all MPW at parity and correct inflection')

# ax.legend()
# ax.set_xlabel("FPR state 1")
# ax.set_ylabel("FPR state 2")
# Out:
# 244227
# 1876
# 496040

# %% [markdown]
# Half of all MP conflicts are between states in categories 1-4-5. However, only roughly 1% of these cases actually translates into a war

# %%
# power transition thesis: inflectionpoints, FPR and parity

fig = plt.figure(1)
ax = fig.add_subplot(111)
a = "MPW"
b = "Inflection-point-end1"
c = "Inflection-point-end2"
d = "Power-end1"
e = "Power-end2"
f = "top-dog"
g = "FPR-end1"
h = "FPR-end2"

outcome1 = outcomes[a]
outcome2 = outcomes[b]
outcome3 = outcomes[c]
outcome4 = outcomes[d]
outcome5 = outcomes[e]
outcome6 = outcomes[f]
outcome7 = outcomes[g]
outcome8 = outcomes[h]


logical1 = outcome1 != 0
logical2 = outcome9 != 0
outcome2 = outcome2[logical1]
outcome3 = outcome3[logical1]
outcome2 = outcome2[logical2]
outcome3 = outcome3[logical2]
logical3 = (outcome2 == 1) & (outcome3 == 5)
logical4 = (outcome2 == 1) & (outcome3 == 4)
logical5 = (outcome2 == 4) & (outcome3 == 1)
logical6 = (outcome2 == 4) & (outcome3 == 5)
logical7 = (outcome2 == 5) & (outcome3 == 1)
logical8 = (outcome2 == 5) & (outcome3 == 4)
logical9 = (outcome2 == 1) & (outcome3 == 1)

outcome16 = abs(outcome4[logical1] - outcome5[logical1]) ## power difference
outcome17 = outcome16 / outcome4[logical1]  
outcome18 = outcome16 / outcome5[logical1] 

#  select only those cases where the percentage of power differential is larger than some value
outcome9 = np.zeros(outcome17.shape)
percentage = 1
# for j, entry in enumerate(outcome9):
for j, item in enumerate(outcome17):
    if item > percentage:
        outcome9[j] = 1
          
for j, item in enumerate(outcome18):
    if item > percentage:
        outcome9[j] = 1

outcome20 = outcome7[logical1]
outcome20 = outcome20[logical2]
outcome21 = outcome8[logical1]
outcome21 = outcome21[logical2]
logical = (logical3 | logical4 | logical5 | logical6 | logical7 | logical8 | logical9 )

outcome20 = outcome20[logical]
outcome21 = outcome21[logical]
# waar het allemaal om draait

outcome01 = outcomes[g]
outcome02 = outcomes[h]
outcome01 = outcome01[logical1]
outcome02 = outcome02[logical1]

ax.scatter(outcome01, outcome02, color='green', label='all MPW')
ax.scatter(outcome20, outcome21, color='red', label='all MPW at parity and correct inflection')

print len(outcome20)
print len(outcome01)

logical01 = (outcome20 > 5) & (outcome21 < 5)
logical02 = (outcome20 < 5) & (outcome21 > 5)
logical03 = logical01 | logical02

print len(outcome20[logical03])
print len(outcome21[logical03])

ax.scatter(outcome20[logical03], outcome21[logical03], color='yellow', label= 'complete according to power transition')
ax.legend()
ax.set_xlabel("FPR state 1")
ax.set_ylabel("FPR state 2")
# Out:
# 336
# 64879
# 94
# 94

# %% [markdown]
# # In only roughly 1% of the cases, two major powers fight eachother at power parity in the correct inflection points.

# %%
fig = plt.figure(1)
ax = fig.add_subplot(111)

outcome9 = outcomes["MPW"]
logical1 = outcome9 == 1

outcome1 = outcomes["Conflict-level-end1end2"]
outcome1 = outcome1[logical1]
outcome2 = outcomes["Power-end1"]
outcome2 = outcome2[logical1]
outcome3 = outcomes["Power-end2"]
outcome3 = outcome3[logical1]
outcome4 = abs(outcome2-outcome3)
outcome5 = outcomes["FPR-end1"]
outcome5 = outcome5[logical1]
outcome6 = outcomes["FPR-end2"]
outcome6 = outcome6[logical1]
outcome7 = outcomes["polarisation"]
outcome7 = outcome7[logical1]
outcome8 = outcomes["top-dog"]
outcome8 = outcome8[logical1]

logical = outcome1 == 5

print len(outcome1[logical])

# ax.hist(outcome2[logical])
# ax.hist( outcome3[logical])
# ax.hist( outcome4[logical])
# ax.hist( outcome5[logical])
# ax.hist( outcome6[logical])
# ax.hist( outcome7[logical])
ax.hist( outcome8[logical])


plt.show()

# print len(outcome3[logical])
# Out:
# 1000

# %%
# hypothesis 1

fig = plt.figure(1)
ax = fig.add_subplot(111)
a = "MPW"
b = "Inflection-point-end1"
c = "Inflection-point-end2"
d = "Power-end1"
e = "Power-end2"
f = "top-dog"

outcome1 = outcomes[a]
outcome2 = outcomes[b]
outcome3 = outcomes[c]
outcome4 = outcomes[d]
outcome5 = outcomes[e]
outcome6 = abs(outcome4[logical2] - outcome5[logical2])
outcome7 = abs(outcome4[logical] - outcome5[logical])
outcome8 = outcomes[f]

logical3 = (outcome3 == 5) & (outcome2 == 4)
logical4 = (outcome3 == 1) & (outcome2 == 4)
logical5 = (outcome3 == 1) & (outcome2 == 1)
logical6 = (outcome3 == 5) & (outcome2 == 1)
logical7 = (outcome3 == 4) & (outcome2 == 4) & (outcome8 == 3)
logical8 = logical2 & logical7
logical2 = outcome1 != 0
logical = logical2 & (logical3 | logical4 | logical5 | logical6)

# ax.scatter(outcome4[logical2],outcome5[logical2] ,color='blue')
# ax.scatter(outcome4[logical8],outcome5[logical8],color='red')
# ax.scatter(outcome4[logical],outcome5[logical],color='green')
# ax.set_xlabel(d)
# ax.set_ylabel(e)

# ax.hist(outcome6, color='blue')
ax.hist((abs(outcome4[logical8] - outcome5[logical8])), color='green')
ax.hist(outcome7, color='red')
# Out:
# (array([ 610.,  391.,  172.,   89.,   59.,   33.,   18.,    2.,    1.,    1.]),
#  array([  4.18857596e-04,   1.46592092e+00,   2.93142298e+00,
#           4.39692504e+00,   5.86242710e+00,   7.32792916e+00,
#           8.79343122e+00,   1.02589333e+01,   1.17244353e+01,
#           1.31899374e+01,   1.46554395e+01]),
#  <a list of 10 Patch objects>)

# %%
# hypothesis 2

fig = plt.figure(1)
ax = fig.add_subplot(111)
a = "MPW"
b = "time-since-MPW"
c = "time-since-transition"

outcome1 = outcomes[a]
outcome2 = outcomes[b]
outcome3 = outcomes[c]

outcome3 = outcome3 * -1

logical = (outcome1 != 0 )

ax.hist(outcome2[logical], 100, color = "red")
ax.hist(outcome3[logical], 100, color = "Green")

ax.set_xlim([-25,25])
ax.set_xlabel("time")
ax.set_ylabel("cases")

# %%
# hypothesis 3

fig = plt.figure(1)
ax = fig.add_subplot(111)
a = "MPW"
b = "expected-transition"


outcome1 = outcomes[a]
outcome2 = outcomes[b]

logical = (outcome1 != 0 )

ax.hist(outcome2[logical])
ax.set_xlabel(b)
ax.set_ylabel("cases")

# %%
# hypothesis 4

# fig = plt.figure(1)
# ax = fig.add_subplot(111)
a = "MPW"
b = "polarisation"
c = "Interdependence-end1end2"

outcome1 = outcomes[a]
outcome2 = outcomes[b]
outcome3 = outcomes[c]

logical = (outcome1 != 0)

# ax.scatter(outcome2[logical],outcome3[logical],color='green')

ax = sns.jointplot(outcome2[logical], outcome3[logical], kind='scatter')
# ax.set_xlabel(b)
# ax.set_ylabel(c)

# print scipy.stats.pearsonr(outcome2, outcome3)

# %%
# hypothesis 5

fig = plt.figure(1)
ax = fig.add_subplot(111)
a = "MPW"
b = "polarisation"
c = "MPW-polarity"

outcome1 = outcomes[a]
outcome2 = outcomes[b]
outcome3 = outcomes[c]

logical = (outcome1 != 0)

ax.scatter(outcome2[logical],outcome3[logical],color='green')
ax.set_xlabel(b)
ax.set_ylabel(c)

# %%
# hypothesis 6

fig = plt.figure(1)
ax = fig.add_subplot(111)
a = "MPW"
c = "MPW-polarity"

outcome1 = outcomes[a]
outcome3 = outcomes[c]

logical = (outcome1 != 0)

ax.hist(outcome3[logical],color='green')
ax.set_xlabel("Polarity")
ax.set_ylabel("Cases")

# %%
# hypothesis 7

fig = plt.figure(1)
ax = fig.add_subplot(111)
# ax2 = fig.add_subplot(212)
a = "MPW"
d = "Power-end1"
e = "Power-end2"

outcome1 = outcomes[a]
outcome4 = outcomes[d]
outcome5 = outcomes[e]
outcome6 = abs(outcome4 - outcome5)

logical = (outcome1 != 0)

# ax.scatter(outcome4[logical],outcome5[logical],color='green')
ax.hist (outcome6[logical], color='green')
ax.set_xlabel("Difference in power")
ax.set_ylabel("cases")

# %%
# hypothesis 8

fig = plt.figure(1)
ax = fig.add_subplot(111)
a = "MPW"
b = "Interdependence-end1end2"

outcome1 = outcomes[a]
outcome2 = outcomes[b]

logical = outcome1 != 0

ax.hist(outcome2[logical], 100)
ax.set_xlabel("interdependence")
ax.set_ylabel("cases")
ax.set_xlim([0,2])
# Out:
# (0, 2)

# %%
# hypothesis 9

fig = plt.figure(1)
ax = fig.add_subplot(111)
a = "MPW"
b = "FPR-end1"
c = "FPR-end2"

outcome1 = outcomes[a]
outcome2 = outcomes[b]
outcome3 = outcomes[c]
outcome4 = outcome2 - outcome3

logical = outcome1 != 0 
# ax.scatter(outcome2[logical],outcome3[logical],color='green')

ax.set_xlabel(b)
ax.set_ylabel(c)

ax.hist (outcome4[logical], color='green')
ax.set_xlabel("Difference in satisfaction")
ax.set_ylabel("cases")

# print scipy.stats.pearsonr(outcome2[logical], outcome3[logical])

# %%
b = "MPW"
d = "Inflection-point-end1"
a = "Inflection-point-end2"

outcome1 = outcomes[b]
outcome2 = outcomes[d]
outcome3 = outcomes[a]

logical3 = outcome3 > 5
logical2 = outcome1 != 0
logical = logical2 & logical3

ax = sns.jointplot(outcome2[logical], outcome3[logical], kind='scatter')

ax.set_xlabel(d)
ax.set_ylabel(a)
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-56-e09bf2bc5077> in <module>()
#      11 logical = logical2 & logical3
#      12
# ---> 13 ax = sns.jointplot(outcome2[logical], outcome3[logical], kind='scatter')
#      14
#      15 ax.set_xlabel(d)
#
# C:\Users\rluteijn\Anaconda\lib\site-packages\seaborn\distributions.pyc in jointplot(x, y, data, kind, stat_func, color, size, ratio, space, dropna, xlim, ylim, joint_kws, marginal_kws, annot_kws)
#     981         marginal_kws.setdefault("kde", False)
#     982         marginal_kws.setdefault("color", color)
# --> 983         grid.plot_marginals(distplot, **marginal_kws)
#     984
#     985     elif kind.startswith("hex"):
#
# C:\Users\rluteijn\Anaconda\lib\site-packages\seaborn\axisgrid.pyc in plot_marginals(self, func, **kwargs)
#    1226         kwargs["vertical"] = True
# ...

# %%
fig = plt.figure(1)
ax = fig.add_subplot(111)
a = "MPW"
b = "max-conflict-level"
c = "Conflict-level-end1end2"

outcome1 = outcomes[a]
outcome2 = outcomes[b]
outcome3 = outcomes[c]
outcome4 = outcome3 - outcome2

logical = outcome1 != 0 

ax.scatter(outcome2[logical],outcome3[logical],color='green')
# ax.hist(outcome4[logical])f

ax.set_xlabel("maximum conflict level")
ax.set_ylabel("actual conflict level")

# %%
# fig = plt.figure(1)
# ax = fig.add_subplot(111)
a = "MPW"
b = "top-dog"
c = "expected-transition"
d = "Inflection-point-end1"

outcome1 = outcomes[a]
outcome2 = outcomes[b]
outcome3 = outcomes[c]
outcome4 = outcomes[d]


logical = outcome1 != 0 

# ax.scatter(outcome2[logical],outcome4[logical],color='green')
sns.jointplot(outcome2[logical], outcome4[logical], kind='scatter')
# ax.hist(outcome2[logical])

# ax.set_xlabel("maximum conflict level")
# ax.set_ylabel("actual conflict level")

# %%
fig = plt.figure(1)
ax = fig.add_subplot(111)
a = "MPW"
b = "MPW-ideology-similarity"
c = "Interdependence-end1end2"

outcome1 = outcomes[a]
outcome2 = outcomes[b]
outcome3 = outcomes[c]

logical = outcome1 != 0 

ax.scatter(outcome2[logical],outcome3[logical],color='green')
# ax.hist(outcome4[logical])

ax.set_xlabel("ideology simularity")
ax.set_ylabel("interdependence")

# %%
fig = plt.figure(1)
ax = fig.add_subplot(111)
a = "MPW"
b = "assessment1"
c = "assessment2"
d = "FPR-end1"
e = "FPR-end2"

outcome1 = outcomes[a]
outcome2 = outcomes[b]
outcome3 = outcomes[c]
outcome4 = outcomes[d]
outcome5 = outcomes[e]

logical = outcome1 != 0 

# ax.scatter(outcome2[logical],outcome4[logical],color='green')
ax.scatter(outcome3[logical],outcome5[logical],color='red')
# ax.hist(outcome4[logical])

ax.set_xlabel("assessment")
ax.set_ylabel("dissatisfaction")

# %%
fig = plt.figure(1)
ax = fig.add_subplot(111)
b = "MPW"

# c = "MPW-ideology-similarity"
# d = "Conflict-level-end1end2"
# d = "MPW-technological-advancement1"
# a = "MPW-technological-advancement2"
# a = "top-dog"
# a = "Interdependence-end1end2"
# a = "MPW-risk-averseness1"
# a = "MPW-risk-averseness2"

# a = "MPW-type-of-conflict"
# a = "max-conflict-level"
# d = "time-since-MPW"
# a = "expected-transition"
# d = "FPR-end1"
# a = "FPR-end2"
d = "Inflection-point-end1"
a = "Inflection-point-end2"
# a = "Power-end1"
# d = "Power-end2"

# a = "polarisation"
# a = "MPW-polarity"
# a = "assessment1"
# a = "assessment2"
# a = "time-since-transition"
# a = "output-multiple-MP1"
# a = "output-multiple-MP2"

outcome1 = outcomes[b]
outcome2 = outcomes[d]
outcome3 = outcomes[a]

value1 = 0

logical3 = outcome3 > 11
logical2 = outcome2 != value1
logical = outcome1 != value1

# numBins = 50
# ax.hist(outcome2[logical],numBins,color='green')
# ax.scatter(outcome2[logical], outcome3[logical], s=np.square(s)*area_scale)
# ax.set_xlabel(d)
# ax.set_ylabel(a)

# ax.set_ylim([0,11])

# print len(outcome3[logical3])
# print len(outcome1[logical])
# print len(outcome1[logical2])
# print np.amax(outcome3[logical])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-fedc787e1b23> in <module>()
#      57
#      58 fn = r'C:\Users\rluteijn\Documents\GitHub\msc_thesis\src/data/revised.tar.gz'
# ---> 59 save_results(results1, fn)
#      60
#
# C:\Users\rluteijn\Documents\GitHub\EMAworkbench\src\expWorkbench\util.pyc in save_results(results, file_name)
#     140
#     141         # write outcome metadata
# --> 142         outcome_names = outcomes.keys()
#     143         outcome_meta = ["{},{}".format(outcome, outcomes[outcome].shape)
#     144                         for outcome in outcome_names]
#
# AttributeError: 'tuple' object has no attribute 'keys'

# %%
b = "MPW"
d = "Inflection-point-end1"
a = "Inflection-point-end2"

outcome1 = outcomes[b]
outcome2 = outcomes[d]
outcome3 = outcomes[a]

value1 = 0
logical3 = outcome3 > 11
logical2 = outcome2 != value1
logical = outcome1 != value1

sns.heatmap((outcome2[logical], outcome3[logical]))

# %%
a = "FPR-end1"
b = "FPR-end2"
c = "Inflection-point-end1"
d = "Inflection-point-end2"
e = "Power-end1"
f = "Power-end2"
h = "Conflict-level-end1end2"

n = "polarisation"
m = "MPW-polarity"
o = "assessment1"
p = "assessment2"
q = "time-since-transition"
r = "output-multiple-MP1"
s = "output-multiple-MP2"

outcome1 = outcomes[n]
outcome2 = outcomes[m]
outcome3 = outcomes[o]
outcome4 = outcomes[p]
outcome5 = outcomes[q]
outcome6 = outcomes[r]
outcome7 = outcomes[s]

outcome8 = outcomes[a]
outcome9 = outcomes[b]
outcome10 = outcomes[c]
outcome11 = outcomes[d]
outcome12 = outcomes[e]
outcome13 = outcomes[f]
outcome14 = outcomes[h]


# outcome8 = abs(outcome1 - outcome2)

value1 = 0

logical = outcome1 != value1

fig = plt.figure(1)
ax = fig.add_subplot(111)
# ax2 = fig.add_subplot(172)
# ax3 = fig.add_subplot(173)
# ax4 = fig.add_subplot(174)
# ax5 = fig.add_subplot(175)
# ax6 = fig.add_subplot(176)
# ax7 = fig.add_subplot(177)


# print outcome1[logical]

# numBins = 50
# ax.scatter(outcome11[logical],outcome13[logical],)
# ax.hist(outcome2[logical],numBins,color='green',alpha=0.8)
# ax.hist(outcome3[logical],numBins,color='green',alpha=0.8)
# ax.hist(outcome4[logical],numBins,color='green',alpha=0.8)
# ax.hist(outcome5[logical],numBins,color='green',alpha=0.8)
# ax.hist(outcome6[logical],numBins,color='green',alpha=0.8)
# ax.hist(outcome7[logical],numBins,color='green',alpha=0.8)
# ax.set_xlabel('Difference in FPR')
# ax.set_ylabel('Cases')
# ax.set_title('Histogram FPR')
# ax.legend( (rects1[0], rects2[0]), ('Men', 'Women') )

# sizes = np.array(count.values())**2
# plt.scatter(x, y, s=sizes, marker='o', c=sizes)


plt.savefig(r"C:\Users\rluteijn\Documents\GitHub\msc_thesis\src\Pictures\Histogram_{}.png".format("dxf"), dpi=600)

# %%
n = "polarisation"
m = "MPW-polarity"
o = "assessment1"
p = "assessment2"
q = "time-since-transition"
r = "output-multiple-MP1"
s = "output-multiple-MP2"

outcome1 = outcomes[n]
outcome2 = outcomes[m]
outcome3 = outcomes[o]
outcome4 = outcomes[p]
outcome5 = outcomes[q]
outcome6 = outcomes[r]
outcome7 = outcomes[s]

# outcome8 = abs(outcome1 - outcome2)

value1 = 0

logical = outcome1 != value1

fig = plt.figure(1)
ax = fig.add_subplot(111)
# ax2 = fig.add_subplot(172)
# ax3 = fig.add_subplot(173)
# ax4 = fig.add_subplot(174)
# ax5 = fig.add_subplot(175)
# ax6 = fig.add_subplot(176)
# ax7 = fig.add_subplot(177)


# print outcome1[logical]

numBins = 50
# ax.hist(outcome1[logical],numBins,color='green',alpha=0.8)
# ax.hist(outcome2[logical],numBins,color='green',alpha=0.8)
# ax.hist(outcome3[logical],numBins,color='green',alpha=0.8)
# ax.hist(outcome4[logical],numBins,color='green',alpha=0.8)
# ax.hist(outcome5[logical],numBins,color='green',alpha=0.8)
# ax.hist(outcome6[logical],numBins,color='green',alpha=0.8)
ax.hist(outcome7[logical],numBins,color='green',alpha=0.8)
# ax.set_xlabel('Difference in FPR')
# ax.set_ylabel('Cases')
# ax.set_title('Histogram FPR')
# ax.legend( (rects1[0], rects2[0]), ('Men', 'Women') )

plt.savefig(r"C:\Users\rluteijn\Documents\GitHub\msc_thesis\src\Pictures\Histogram_{}.png".format(s), dpi=600)

# %%
fig = plt.figure(1)
ax = fig.add_subplot(111)

a = "Output-FPR-end1"
b = "Output-FPR-end2"
c = "Output-Inflection-point-end1"
d = "Output-Inflection-point-end2"
e = "Output-Power-end1"
f = "Output-Power-end2"
g = "Output-Interdependence-end1end2"
h = "Output-Conflict-level-end1end2"

outcomea = outcomes[a]
outcomea = outcomea[:, 0]
outcomeb = outcomes[b]
outcomeb = outcomeb[:, 0]
outcomec = outcomes[c]
outcomec = outcomec[:, 0]
outcomed = outcomes[d]
outcomed = outcomed[:, 0]
outcomee = outcomes[e]
outcomee = outcomee[:, 0]
outcomef = outcomes[f]
outcomef = outcomef[:, 0]
outcomeg = outcomes[g]
outcomeg = outcomeg[:, 0]
outcomeh = outcomes[h]
outcomeh = outcomeh[:, 0]

Y = ['outcomea', 'outcomeb', 'outcomec', 'outcomed', 'outcomee', 'outcomef', 'outcomeg', 'outcomeh']
# Z = ('outcomea', 'outcomeb', 'outcomec', 'outcomed', 'outcomee', 'outcomef', 'outcomeg', 'outcomeh')
Z = (outcomea, outcomeb, outcomec, outcomed, outcomee, outcomef, outcomeg, outcomeh)

scipy.stats.pearsonr(outcomea, outcomeb) ## indivually for outcomes this works

Y.corr(Z)

# from scipy import stats
# # Y and Z are numpy arrays or lists of variables 
# stats.pearsonr(Y, Z)


# sns.corrplot(, 
#              names = (a, b, c, d, e, f, g, h),
#              annot = True,
#              sig_stars = False
# #            sig_tail='both'
# )

# f, ax = plt.subplots(figsize=(9, 9))
# cmap = sns.diverging_palette(220, 10, as_cmap=True)
# sns.corrplot(x, annot=False, sig_stars=False,
#              names = ('a', 'b'),##, c, d, e, f, g, h),
#              diag_names=False, cmap=cmap, ax=ax)
# f.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-218db50c67b5> in <module>()
#      39 scipy.stats.pearsonr(outcomea, outcomeb) ## indivually for outcomes this works
#      40
# ---> 41 Y.corr(Z)
#      42
#      43 # from scipy import stats
#
# AttributeError: 'list' object has no attribute 'corr'

# %%
n = "FPR-end1"
m = "FPR-end2"
outcome1 = outcomes[n]
# outcome1 = outcome1[:, 0]
outcome2 = outcomes[m]
# outcome2 = outcome2[:, 0]
outcome3 = abs(outcome1 - outcome2)

value1 = 0

logical = outcome1 != value1

fig = plt.figure(1)
ax = fig.add_subplot(111)

# print outcome1[logical]

numBins = 50
ax.hist(outcome1[logical],numBins,color='green',alpha=0.8)
# ax.hist(outcome2,numBins,color='red',alpha=0.8)
# ax.hist(outcome3,numBins,color='blue',alpha=0.8)
# ax.set_xlabel('Difference in FPR')
# ax.set_ylabel('Cases')
# ax.set_title('Histogram FPR')
# ax.legend( (rects1[0], rects2[0]), ('Men', 'Women') )

# plt.savefig(r"C:\Users\rluteijn\Documents\GitHub\msc_thesis\src\Pictures\Histogram_{}.png".format(n), dpi=600)
# Out:
# (array([ 133.,   13.,    9.,    7.,   12.,    9.,    6.,    9.,    9.,
#            4.,    3.,    4.,    0.,    2.,    4.,    2.,    1.,    1.,
#            3.,    1.,    1.,    1.,    2.,    2.,    2.,    2.,    2.,
#            0.,    2.,    3.,    6.,    0.,    4.,    1.,    1.,    3.,
#            1.,    2.,    4.,    4.,    2.,    8.,    6.,    0.,    3.,
#           10.,    7.,    8.,   41.,    6.]),
#  array([  0.        ,   0.20636124,   0.41272249,   0.61908373,
#           0.82544497,   1.03180622,   1.23816746,   1.4445287 ,
#           1.65088994,   1.85725119,   2.06361243,   2.26997367,
#           2.47633492,   2.68269616,   2.8890574 ,   3.09541865,
#           3.30177989,   3.50814113,   3.71450238,   3.92086362,
#           4.12722486,   4.3335861 ,   4.53994735,   4.74630859,
#           4.95266983,   5.15903108,   5.36539232,   5.57175356,
#           5.77811481,   5.98447605,   6.19083729,   6.39719854,
# ...

# %%
n = "Output-Inflection-point-end1"
m = "Output-Inflection-point-end2"
outcome1 = outcomes[n]
outcome1 = outcome1[:, 0]
outcome2 = outcomes[m]
outcome2 = outcome2[:, 0]
outcome3 = abs(outcome1 - outcome2)

fig = plt.figure(1)
ax = fig.add_subplot(111)
ax.set_xlabel('Difference in inflectionpoint')
ax.set_ylabel('Cases')
ax.set_title('Histogram Differential inflection points')

numBins = 50
# ax.hist(outcome1,numBins,color='green',alpha=0.8)
# ax.hist(outcome2,numBins,color='red',alpha=0.8)
ax.hist(outcome3,numBins,color='blue',alpha=0.8)

plt.savefig(r"C:\Users\rluteijn\Documents\GitHub\msc_thesis\src\Pictures\Histogram_{}.png".format(n), dpi=600)

# %%
n = "Output-Power-end1"
m = "Output-Power-end2"
outcome1 = outcomes[n]
outcome1 = outcome1[:, 0]
outcome2 = outcomes[m]
outcome2 = outcome2[:, 0]
outcome3 = abs(outcome1 - outcome2)

fig = plt.figure(1)
ax = fig.add_subplot(111)

numBins = 50
# ax.hist(outcome1,numBins,color='green',alpha=0.8)
# ax.hist(outcome2,numBins,color='red',alpha=0.8)
ax.hist(outcome3,numBins,color='blue',alpha=0.8)

ax.set_xlabel('Difference in Power')
ax.set_ylabel('Cases')
ax.set_title('Histogram Power differential')

plt.savefig(r"C:\Users\rluteijn\Documents\GitHub\msc_thesis\src\Pictures\Histogram_{}.png".format(n), dpi=600)

# %%
n = "Output-Interdependence-end1end2"
m = "Output-Conflict-level-end1end2"
outcome1 = outcomes[n]
outcome1 = outcome1[:, 0]
outcome2 = outcomes[m]
outcome2 = outcome2[:, 0]

fig = plt.figure(1)
ax = fig.add_subplot(111)

numBins = 50
# ax.hist(outcome1,numBins,color='green',alpha=0.8)
ax.hist(outcome2,numBins,color='blue',alpha=0.8)
ax.set_xlabel('Conflict level')
ax.set_ylabel('Cases')
ax.set_title('Histogram Conflict level')

plt.savefig(r"C:\Users\rluteijn\Documents\GitHub\msc_thesis\src\Pictures\Histogram_{}.png".format(m), dpi=600)

# %%
outcome1 = outcomes["polarity"]
outcome1 = outcome1["time-of-conflict", 0]
outcome2 = outcomes["Output-Conflict-level-end1end2"]
outcome2 = outcome2[:, 0]

fig = plt.figure(1)
ax = fig.add_subplot(111)

N = 50

colors = np.random.rand(N)
area = np.pi * (15 * np.random.rand(N))**2 # 0 to 15 point radiuses

plt.scatter(outcome1, outcome2, s=area, c=colors, alpha=0.5)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-6-ce88b87c98fb> in <module>()
#       1 outcome1 = outcomes["polarity"]
# ----> 2 outcome1 = outcome1["time-of-conflict", 0]
#       3 outcome2 = outcomes["Output-Conflict-level-end1end2"]
#       4 outcome2 = outcome2[:, 0]
#       5
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
fig, axesdict = pairs_scatter(results, 
                  outcomes_to_show = [
                            "Inflection-point-end1",
                            "Inflection-point-end2",
                            "FPR-end1",
                            "FPR-end2",
                            "Power-end1",
                            "Power-end2",
                            "Interdependence-end1end2",
                            "Conflict-level-end1end2",
                            "polarisation",
                            "MPW-polarity",   
                            "assessment1",   
                            "assessment2",   
                            "time-since-transition",   
                            "output-multiple-MP1",   
                            "output-multiple-MP2",  
                    ],
                  group_by = None,
                  grouping_specifiers = None,
                  ylabels = {},
                  legend=True,
                  point_in_time=-1,
                  filter_scalar=True
                  )

fig.set_size_inches(18.5,10.5)

plt.show()
# Out:
# [INFO/MainProcess] no time dimension found in results
