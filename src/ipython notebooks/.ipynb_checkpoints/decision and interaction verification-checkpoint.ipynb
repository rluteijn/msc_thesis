# %%
import numpy as np
import matplotlib.pyplot as plt

from expWorkbench import ema_logging, load_results, CategoricalUncertainty
from analysis import plotting, plotting_util
from analysis.plotting import lines, KDE, kde_over_time, multiple_densities, envelopes
from analysis.pairs_plotting import pairs_scatter
from analysis.plotting_util import plot_kde, ENVELOPE, ENV_LIN, VIOLIN

ema_logging.log_to_stderr(ema_logging.INFO);

#load the data
fn = r'C:\Users\rluteijn\Documents\GitHub\msc_thesis\src\data\500 runs 6 jan.tar.gz'
experiments, outcomes = load_results(fn)
results = (experiments, outcomes)
# Out:
# [INFO/MainProcess] results loaded succesfully from C:\Users\rluteijn\Documents\GitHub\msc_thesis\src\data\500 runs 6 jan.tar.gz

# %%
fig, axesdict = envelopes(results, 
                  outcomes_to_show = [
                    "count-1", 
                    "count-2", 
                    "count-3", 
                    "count-4", 
                    "count-5", 
                    "count-6", 
                    "count-7", 
                    ],
                  group_by = None,
                  grouping_specifiers = None,
                  density='',
                  fill=False,
                  legend=True,
                  titles={},
                  ylabels={},
                  log=True)
plt.show()
# Out:
# C:\Users\rluteijn\Documents\GitHub\EMAworkbench\src\analysis\plotting_util.py:445: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   if time==None:

# %%
fig, axesdict = envelopes(results, 
                  outcomes_to_show = [
                    "interact-1", 
                    "interact-2", 
                    "interact-3", 
                    "interact-4", 
                    "interact-5", 
#                     "interact-6", 
#                     "interact-7", 
#                     "interact-8", 
#                     "interact-9", 
#                     "interact-10", 
#                     "interact-11", 
#                     "interact-12", 
#                     "interact-13", 
#                     "interact-14", 
#                     "interact-15", 
#                     "interact-16", 
#                     "interact-17", 
#                     "interact-18", 
#                     "interact-19", 
#                     "interact-20", 
#                     "interact-21", 
#                     "interact-22", 
#                     "interact-23", 
                    ],
                  group_by = None,
                  grouping_specifiers = None,
                  density='',
                  fill=False,
                  legend=True,
                  titles={},
                  ylabels={},
                  log=True)
plt.show()

# %%
fig, axesdict = envelopes(results, 
                  outcomes_to_show = [
#                     "interact-1", 
#                     "interact-2", 
#                     "interact-3", 
#                     "interact-4", 
#                     "interact-5", 
                    "interact-6", 
                    "interact-7", 
                    "interact-8", 
                    "interact-9", 
                    "interact-10", 
#                     "interact-11", 
#                     "interact-12", 
#                     "interact-13", 
#                     "interact-14", 
#                     "interact-15", 
#                     "interact-16", 
#                     "interact-17", 
#                     "interact-18", 
#                     "interact-19", 
#                     "interact-20", 
#                     "interact-21", 
#                     "interact-22", 
#                     "interact-23", 
                    ],
                  group_by = None,
                  grouping_specifiers = None,
                  density='',
                  fill=False,
                  legend=True,
                  titles={},
                  ylabels={},
                  log=True)
plt.show()

# %%
fig, axesdict = envelopes(results, 
                  outcomes_to_show = [
#                     "interact-1", 
#                     "interact-2", 
#                     "interact-3", 
#                     "interact-4", 
#                     "interact-5", 
#                     "interact-6", 
#                     "interact-7", 
#                     "interact-8", 
#                     "interact-9", 
#                     "interact-10", 
                    "interact-11", 
                    "interact-12", 
                    "interact-13", 
                    "interact-14", 
                    "interact-15", 
#                     "interact-16", 
#                     "interact-17", 
#                     "interact-18", 
#                     "interact-19", 
#                     "interact-20", 
#                     "interact-21", 
#                     "interact-22", 
#                     "interact-23", 
                    ],
                  group_by = None,
                  grouping_specifiers = None,
                  density='',
                  fill=False,
                  legend=True,
                  titles={},
                  ylabels={},
                  log=True)
plt.show()

# %%
fig, axesdict = envelopes(results, 
                  outcomes_to_show = [
#                     "interact-1", 
#                     "interact-2", 
#                     "interact-3", 
#                     "interact-4", 
#                     "interact-5", 
#                     "interact-6", 
#                     "interact-7", 
#                     "interact-8", 
#                     "interact-9", 
#                     "interact-10", 
#                     "interact-11", 
#                     "interact-12", 
#                     "interact-13", 
#                     "interact-14", 
#                     "interact-15", 
                    "interact-16", 
                    "interact-17", 
                    "interact-18", 
                    "interact-19", 
                    "interact-20", 
                    "interact-21", 
                    "interact-22", 
                    "interact-23", 
                    ],
                  group_by = None,
                  grouping_specifiers = None,
                  density='',
                  fill=False,
                  legend=True,
                  titles={},
                  ylabels={},
                  log=True)
plt.show()
