# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy as sc
import pandas as pa

from expWorkbench import ema_logging, load_results, CategoricalUncertainty
from analysis import plotting, plotting_util
from analysis.plotting import lines, KDE, kde_over_time, multiple_densities, envelopes
from analysis.pairs_plotting import pairs_scatter
from analysis.plotting_util import plot_kde, ENVELOPE, ENV_LIN, VIOLIN, plot_histogram

ema_logging.log_to_stderr(ema_logging.INFO);

#load the data
fn = r'C:\Users\rluteijn\Documents\GitHub\msc_thesis\src\data\8 runs 19 jan.tar.gz'
experiments, outcomes = load_results(fn)
results = (experiments, outcomes)
# Out:
# [INFO/MainProcess] results loaded succesfully from C:\Users\rluteijn\Documents\GitHub\msc_thesis\src\data\8 runs 19 jan.tar.gz

# %%
fig, axesdict = pairs_scatter(results, 
                  outcomes_to_show = [
                    "Output-Inflection-point-end1",
                    "Output-Inflection-point-end2",
                    "Output-FPR-end1",
                    "Output-FPR-end2",
                    "Output-Power-end1",
                    "Output-Power-end2",
                    "Output-Interdependence-end1end2",
                    "Output-Conflict-level-end1end2",
                    ],
                  group_by = None,
                  grouping_specifiers = None,
                  ylabels = {},
                  legend=True,
                  point_in_time=-1,
                  filter_scalar=True
                  )
plt.show()
# Out:
# [INFO/MainProcess] no time dimension found in results

# %%
fig, axesdict = pairs_scatter(results, 
                  outcomes_to_show = [
#                     "Output-Inflection-point-end1",
#                     "Output-Inflection-point-end2",
                    "Output-FPR-end1",
                    "Output-FPR-end2",
#                     "Output-Power-end1",
#                     "Output-Power-end2",
#                     "Output-Interdependence-end1end2",
#                     "Output-Conflict-level-end1end2",
                    ],
                  group_by = None,
                  grouping_specifiers = None,
                  ylabels = {},
                  legend=True,
                  point_in_time=-1,
                  filter_scalar=True
                  )
plt.show()
# Out:
# [INFO/MainProcess] no time dimension found in results

# %%
fig, axesdict = pairs_scatter(results, 
                  outcomes_to_show = [
#                     "Output-Inflection-point-end1",
#                     "Output-Inflection-point-end2",
#                     "Output-FPR-end1",
#                     "Output-FPR-end2",
                    "Output-Power-end1",
                    "Output-Power-end2",
#                     "Output-Interdependence-end1end2",
#                     "Output-Conflict-level-end1end2",
                    ],
                  group_by = None,
                  grouping_specifiers = None,
                  ylabels = {},
                  legend=True,
                  point_in_time=-1,
                  filter_scalar=True
                  )
plt.show()
# Out:
# [INFO/MainProcess] no time dimension found in results

# %%
fig = plt.figure(1, figsize=(9, 6))
ax = fig.add_subplot(111)

from seaborn import corrplot

fig = sns.corrplot(
                    results, 
                    names=[
                    "Output-Inflection-point-end1",
                    "Output-Inflection-point-end2",
                    "Output-FPR-end1",
                    "Output-FPR-end2",
                    "Output-Power-end1",
                    "Output-Power-end2",
                    "Output-Interdependence-end1end2",
                    "Output-Conflict-level-end1end2",
                    ], 
                    annot=True, 
                    sig_stars=True, 
                    sig_tail='both', 
                    sig_corr=True, 
                    cmap="RdBu_r",  
                    cmap_range="full", 
                    cbar=True, 
                    diag_names=True, 
                    method=None, 
                    ax=None, 
                    )

plt.show()
# http://stanford.edu/~mwaskom/software/seaborn/generated/seaborn.corrplot.html#seaborn.corrplot

# %%
fig, axesdict =  sns.clustermap(results, pivot_kws=None, method='average', 
                                metric='euclidean', z_score=None, 
                                standard_scale=None, figsize=None, 
                                cbar_kws=None, row_cluster=True, 
                                col_cluster=True, row_linkage=None, 
                                col_linkage=None, row_colors=None, 
                                col_colors=None, 
                                mask=None, **kwargs)

http://stanford.edu/~mwaskom/software/seaborn/generated/seaborn.clustermap.html#seaborn.clustermap

# %%
fig, axesdict =  sns.jointplot(x, y, data=None, 
                               kind='scatter', 
                               stat_func=<function pearsonr at 0x105210230>, 
                               color=None, size=6, ratio=5, space=0.2, 
                               dropna=True, xlim=None, ylim=None, 
                               joint_kws=None, marginal_kws=None, 
                               annot_kws=None)

http://stanford.edu/~mwaskom/software/seaborn/generated/seaborn.jointplot.html#seaborn.jointplot

# %%
fig, axesdict =  sns.lmplot(x, y, data, hue=None, 
                            col=None, row=None, 
                            palette=None, col_wrap=None, 
                            size=5, aspect=1, 
                            markers='o', sharex=True, 
                            sharey=True, hue_order=None, 
                            col_order=None, row_order=None, 
                            dropna=True, legend=True, 
                            legend_out=True, **kwargs)

http://stanford.edu/~mwaskom/software/seaborn/generated/seaborn.lmplot.html#seaborn.lmplot

# %%
fig, axesdict =  sns.KDEplot(data, data2=None, 
                             shade=False, vertical=False, 
                             kernel='gau', bw='scott', 
                             gridsize=100, cut=3, clip=None, 
                             legend=True, ax=None, 
                             cumulative=False, **kwargs)

http://stanford.edu/~mwaskom/software/seaborn/generated/seaborn.kdeplot.html#seaborn.kdeplot
