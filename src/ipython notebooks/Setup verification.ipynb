# %%
import numpy as np
import matplotlib.pyplot as plt

from expWorkbench import ema_logging, load_results, CategoricalUncertainty
from analysis import plotting, plotting_util
from analysis.plotting import lines, KDE, kde_over_time, multiple_densities, envelopes
from analysis.pairs_plotting import pairs_scatter
from analysis.plotting_util import plot_kde, ENVELOPE, ENV_LIN, VIOLIN

ema_logging.log_to_stderr(ema_logging.INFO);

#load the data
fn = r'C:\Users\rluteijn\Documents\GitHub\msc_thesis\src\data\1000 runs setup verification 7 jan.tar.gz'
experiments, outcomes = load_results(fn)
results = (experiments, outcomes)

fig, axesdict = lines(results, 
                  outcomes_to_show = ["Polarity"
# "def-patches-water ", "should-patches-water "
],
                  group_by = None,
                  grouping_specifiers = None,
                  density='',
#                   fill=False,
                  legend=True,
                  titles={},
                  ylabels={},
                  log=False)
plt.show()
# Out:
# [INFO/MainProcess] results loaded succesfully from C:\Users\rluteijn\Documents\GitHub\msc_thesis\src\data\1000 runs setup verification 7 jan.tar.gz

# %%
fig, axesdict = envelopes(results, 
                  outcomes_to_show = ["min-GDPpercapita ", "max-GDPpercapita "],
                  group_by = None,
                  grouping_specifiers = None,
                  density='',
                  fill=False,
                  legend=True,
                  titles={},
                  ylabels={},
                  log=False)
plt.show()

# %%
fig, axesdict = envelopes(results, 
                  outcomes_to_show = ["amount-capitals ", "min-state ","max-state ", "unassigned-patches " ],
                  group_by = None,
                  grouping_specifiers = None,
                  density='',
                  fill=False,
                  legend=True,
                  titles={},
                  ylabels={},
                  log=False)
plt.show()

# %%
fig, axesdict = envelopes(results, 
                  outcomes_to_show = ["min-patch-population ", "max-patch-population " ],
                  group_by = None,
                  grouping_specifiers = None,
                  density='',
                  fill=False,
                  legend=True,
                  titles={},
                  ylabels={},
                  log=False)
plt.show()

# %%
fig, axesdict = envelopes(results, 
                  outcomes_to_show = ["min-patch-GDPperCapita ", "max-patch-GDPperCapita " ],
                  group_by = None,
                  grouping_specifiers = None,
                  density='',
                  fill=False,
                  legend=True,
                  titles={},
                  ylabels={},
                  log=False)
plt.show()

# %%
fig, axesdict = envelopes(results, 
                  outcomes_to_show = ["min-GDPpercapita-growth ", "max-GDPpercapita-growth " ],
                  group_by = None,
                  grouping_specifiers = None,
                  density='',
                  fill=False,
                  legend=True,
                  titles={},
                  ylabels={},
                  log=False)
plt.show()

# %%
fig, axesdict = envelopes(results, 
                  outcomes_to_show = ["min-Population-growth ", "max-Population-growth" ],
                  group_by = None,
                  grouping_specifiers = None,
                  density='',
                  fill=False,
                  legend=True,
                  titles={},
                  ylabels={},
                  log=False)
plt.show()

# %%
fig, axesdict = envelopes(results, 
                  outcomes_to_show = ["min-economic-size ", "max-economic-size " ],
                  group_by = None,
                  grouping_specifiers = None,
                  density='',
                  fill=False,
                  legend=True,
                  titles={},
                  ylabels={},
                  log=False)
plt.show()

# %%
fig, axesdict = envelopes(results, 
                  outcomes_to_show = ["should-patches-resources", "def-patches-resources" ],
                  group_by = None,
                  grouping_specifiers = None,
                  density='',
                  fill=False,
                  legend=True,
                  titles={},
                  ylabels={},
                  log=False)
plt.show()

# %%
fig, axesdict = envelopes(results, 
                  outcomes_to_show = ["max-GDP ", "min-GDP " ],
                  group_by = None,
                  grouping_specifiers = None,
                  density='',
                  fill=False,
                  legend=True,
                  titles={},
                  ylabels={},
                  log=False)
plt.show()

# %%
fig, axesdict = envelopes(results, 
                  outcomes_to_show = ["max-Population ", "min-Population " ],
                  group_by = None,
                  grouping_specifiers = None,
                  density='',
                  fill=False,
                  legend=True,
                  titles={},
                  ylabels={},
                  log=False)
plt.show()

# %%
fig, axesdict = envelopes(results, 
                  outcomes_to_show = ["max-MilitaryCapabilities ", "min-MilitaryCapabilities " ],
                  group_by = None,
                  grouping_specifiers = None,
                  density='',
                  fill=False,
                  legend=True,
                  titles={},
                  ylabels={},
                  log=False)
plt.show()

# %%
fig, axesdict = envelopes(results, 
                  outcomes_to_show = ["max-MilitarySpending ", "min-MilitarySpending " ],
                  group_by = None,
                  grouping_specifiers = None,
                  density='',
                  fill=False,
                  legend=True,
                  titles={},
                  ylabels={},
                  log=False)
plt.show()

# %%
fig, axesdict = envelopes(results, 
                  outcomes_to_show = ["min-tradepartners ", "max-tradepartners " ],
                  group_by = None,
                  grouping_specifiers = None,
                  density='',
                  fill=False,
                  legend=True,
                  titles={},
                  ylabels={},
                  log=False)
plt.show()

# %%
fig, axesdict = envelopes(results, 
                  outcomes_to_show = ["min-DiplomaticRelations ", "max-DiplomaticRelations " ],
                  group_by = None,
                  grouping_specifiers = None,
                  density='',
                  fill=False,
                  legend=True,
                  titles={},
                  ylabels={},
                  log=False)
plt.show()

# %%
fig, axesdict = envelopes(results, 
                  outcomes_to_show = ["min-friendly-states ", "max-friendly-states " ],
                  group_by = None,
                  grouping_specifiers = None,
                  density='',
                  fill=False,
                  legend=True,
                  titles={},
                  ylabels={},
                  log=False)
plt.show()
